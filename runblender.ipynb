# %% [markdown]
# <a href="https://colab.research.google.com/github/U-Tea/U-Tea/blob/main/runblender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup
# Specify your desired blender version and the path to your blend file within google drive.
#
# ###Info
# If you do need more information on parameters etc. look here: [Blender CLI Wiki](https://docs.blender.org/manual/en/latest/advanced/command_line/arguments.html)

# %% [markdown]
# Use to render a single frame.
# Specify the frame with -f *frame_number*

# %%
#Download Blender from Repository
# !wget https://ftp.halifax.rwth-aachen.de/blender/release/Blender4.5/blender-4.5.4-linux-x64.tar.xz

#Install Blender

# !tar -xf blender-4.5.4-linux-x64.tar.xz


#Download some required libraries (if not already installed)
# !apt install libboost-all-dev
# !apt install libgl1-mesa-dev
# Out:
# --2025-11-14 20:28:35--  https://ftp.halifax.rwth-aachen.de/blender/release/Blender4.5/blender-4.5.4-linux-x64.tar.xz
# Resolving ftp.halifax.rwth-aachen.de (ftp.halifax.rwth-aachen.de)... 137.226.34.46, 2a00:8a60:e012:a00::21
# Connecting to ftp.halifax.rwth-aachen.de (ftp.halifax.rwth-aachen.de)|137.226.34.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 377398712 (360M) [application/octet-stream]
# Saving to: ‘blender-4.5.4-linux-x64.tar.xz’
#
# blender-4.5.4-linux 100%[===================>] 359.92M  17.7MB/s    in 22s
#
# 2025-11-14 20:28:58 (16.1 MB/s) - ‘blender-4.5.4-linux-x64.tar.xz’ saved [377398712/377398712]
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   javascript-common libboost-atomic-dev libboost-atomic1.74-dev
#   libboost-atomic1.74.0 libboost-chrono-dev libboost-chrono1.74-dev
# ...

# %%
# !blender -b v1.blend -E CYCLES -P script.py -o //render_output -f 1
# Out:
# /bin/bash: line 1: blender: command not found

# %%
#Just creating a variable to hold the location of the Blender file and Output file
#The location can also be given in the command that follows instead of creating a variable
blenderFileName = "v1.blend"

tempFile = blenderFileName.split('.')
outputFileName = tempFile[0]

outputFolderName = outputFileName + "ast"


outputFile = outputFolderName + '/' + outputFileName + "_"

# !mkdir -p $outputFolderName

startFrame = 1
endFrame = 10

blenderFile = "v1.blend"
enableGPU = "enable_gpu.py"     # a python script inside Blender
outputFile = "//renders/frame_"

# !./blender-4.5.4-linux-x64/blender \
    -b /content/v1.blend \
    -P /content/script.py \
    -o /content/output.mp4 \
    -a
# Out:
# Blender 4.5.4 LTS (hash b3efe983cc58 built 2025-10-28 01:32:34)
# Read blend: "/content/v1.blend"
# Fra:1 Mem:13.17M (Peak 13.17M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | path266
# Fra:1 Mem:13.26M (Peak 13.26M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | path267
# Fra:1 Mem:13.36M (Peak 13.36M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | rect3
# Fra:1 Mem:13.36M (Peak 13.36M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | path184.001
# Fra:1 Mem:13.46M (Peak 13.46M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | text233.001
# Fra:1 Mem:13.63M (Peak 13.63M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | text234.001
# Fra:1 Mem:13.88M (Peak 13.88M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | text235.001
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
